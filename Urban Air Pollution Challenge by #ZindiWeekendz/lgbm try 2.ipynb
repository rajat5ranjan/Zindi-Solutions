# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
np.random.seed=1994

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
pd.set_option('display.max_rows', 500)

# pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)

# %%
train=pd.read_csv('/content/gdrive/My Drive/Competetion_ML/Zindi/Train.csv')
test=pd.read_csv('/content/gdrive/My Drive/Competetion_ML/Zindi/Test.csv')
s=pd.read_csv('/content/gdrive/My Drive/Competetion_ML/Zindi/SampleSubmission (1).csv')

# %%
# df=train.append(test,ignore_index=True)
# df.head()
# Out:
#         Place_ID X Date  ... L3_CH4_solar_zenith_angle
# 0  010Q650 X 2020-01-02  ...                 22.545118
# 1  010Q650 X 2020-01-03  ...                 19.293652
# 2  010Q650 X 2020-01-04  ...                       NaN
# 3  010Q650 X 2020-01-05  ...                       NaN
# 4  010Q650 X 2020-01-06  ...                       NaN
#
# [5 rows x 82 columns]

# %%
df=train.append(test,ignore_index=True)
df.head()
# Out:
#         Place_ID X Date  ... L3_CH4_solar_zenith_angle
# 0  010Q650 X 2020-01-02  ...                 22.545118
# 1  010Q650 X 2020-01-03  ...                 19.293652
# 2  010Q650 X 2020-01-04  ...                       NaN
# 3  010Q650 X 2020-01-05  ...                       NaN
# 4  010Q650 X 2020-01-06  ...                       NaN
#
# [5 rows x 82 columns]

# %%
def create_features(df, label=None,seg=None):
    """
    Creates time series features from datetime index.
    """
    df = df.copy()

    df['date'] = pd.to_datetime(df['Date'],format='%Y-%m-%d')
    df['dayofweek'] = df['date'].dt.dayofweek
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['week'] = df['date'].dt.week
    df['is_month_start']=df['date'].dt.is_month_start
    df['is_month_end']=df['date'].dt.is_month_end
    df['is_quarter_start']=df['date'].dt.is_quarter_start
    df['is_quarter_end']=df['date'].dt.is_quarter_end
    df['is_year_start']=df['date'].dt.is_year_start
    df['is_year_end']=df['date'].dt.is_year_end
    df['Semester'] = np.where(df['quarter'].isin([1,2]),1,2)
    df['Date']=pd.factorize(df['Date'])[0]


    df['Place_ID']=df['Place_ID'].astype('category')
    l=['precipitable_water_entire_atmosphere','relative_humidity_2m_above_ground',
                                                        'specific_humidity_2m_above_ground','temperature_2m_above_ground','u_component_of_wind_10m_above_ground',
                                                        'v_component_of_wind_10m_above_ground']

    df[[x+'cumsum' for x in l]]=df.sort_values('Date').groupby('Place_ID').cumsum()[l].sort_index()
    df[[x+'diff' for x in l]]=df.sort_values('Date').groupby('Place_ID')[l].diff().sort_index()
    return df.drop(['date'],axis=1)

# %%
d={}
for k in [x for x in df.columns if x not in ['Place_ID X Date', 'Date', 'Place_ID', 'target', 'target_min',
      'target_max', 'target_variance', 'target_count']]:
  d[k]=['min','max','sum','mean','std']


# t1 = df.groupby('Place_ID').agg(d)
# t1.columns=['LC_' + '_'.join(col).strip() for col in t1.columns.values]
# t1.reset_index(inplace=True)
# df = df.merge(t1,on='Place_ID',how='left')
t1 = df.groupby('Date').agg(d)
t1.columns=['LD_' + '_'.join(col).strip() for col in t1.columns.values]
t1.reset_index(inplace=True)
df = df.merge(t1,on='Date',how='left')

# %%
df=create_features(df)
df.shape
# Out:
# (46693, 478)

# %%
df_train=df[df['target'].isnull()==False].copy()
df_test=df[df['target'].isnull()==True].copy()

print(df_train.shape,df_test.shape)
# Out:
# (30557, 478) (16136, 478)

# %%
from lightgbm import LGBMClassifier,LGBMRegressor
from sklearn.model_selection import StratifiedKFold,train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error

# %%
features=[x for x in df.columns if x not in ['target', 'target_count', 'target_max', 'target_min','target_variance','Place_ID']]

# %%
X,y=df_train[features].drop(['Place_ID X Date'],axis=1),df_train['target']
Xtest=df_test[features].drop(['Place_ID X Date'],axis=1)
y_bin = pd.qcut(y,10,labels=False,duplicates='drop')
print(y_bin)


print(X.shape,Xtest.shape)
X_train,X_val,y_train,y_val = train_test_split(X,y,test_size=0.25,random_state = 1994,stratify=y_bin)
# Out:
# 0        3
# 1        4
# 2        2
# 3        4
# 4        1
#         ..
# 30552    1
# 30553    5
# 30554    7
# 30555    8
# 30556    7
# Name: target, Length: 30557, dtype: int64
# (30557, 471) (16136, 471)

# %%
# s.to_csv('colabtry4.csv',index=False) ,reg_alpha=1,reg_lambda=10
# s.target.describe()
err=[]
y_pred_tot=[]
from sklearn.model_selection import KFold,StratifiedKFold
fold=StratifiedKFold(n_splits=10,shuffle=True,random_state=1994)
i=1
for train_index, test_index in fold.split(X,y_bin):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    m=LGBMRegressor(n_estimators=10000,random_state=1994,learning_rate=0.03,num_leaves=50,boosting_type='gbdt',feature_fraction=0.6,
                objective='regression',min_child_samples=12)
    m.fit(X_train,y_train,eval_set=[(X_test, y_test)],eval_metric='rmse', early_stopping_rounds=200,verbose=400)
    preds=m.predict(X_test)
    print("err: ",np.sqrt(mean_squared_error(y_test,preds)))
    err.append(np.sqrt(mean_squared_error(y_test,preds)))
    p = m.predict(Xtest)
    i=i+1
    y_pred_tot.append(p)
# Out:
# Training until validation scores don't improve for 200 rounds.
# [400]	valid_0's rmse: 27.6809	valid_0's l2: 766.234
# [800]	valid_0's rmse: 26.6669	valid_0's l2: 711.122
# [1200]	valid_0's rmse: 26.1398	valid_0's l2: 683.291
# [1600]	valid_0's rmse: 25.8237	valid_0's l2: 666.864
# [2000]	valid_0's rmse: 25.6315	valid_0's l2: 656.972
# [2400]	valid_0's rmse: 25.5072	valid_0's l2: 650.619
# [2800]	valid_0's rmse: 25.4322	valid_0's l2: 646.795
# [3200]	valid_0's rmse: 25.3661	valid_0's l2: 643.437
# [3600]	valid_0's rmse: 25.3048	valid_0's l2: 640.331
# [4000]	valid_0's rmse: 25.2527	valid_0's l2: 637.699
# [4400]	valid_0's rmse: 25.2198	valid_0's l2: 636.038
# [4800]	valid_0's rmse: 25.1916	valid_0's l2: 634.617
# [5200]	valid_0's rmse: 25.1672	valid_0's l2: 633.386
# [5600]	valid_0's rmse: 25.1411	valid_0's l2: 632.077
# [6000]	valid_0's rmse: 25.1218	valid_0's l2: 631.105
# [6400]	valid_0's rmse: 25.1165	valid_0's l2: 630.837
# [6800]	valid_0's rmse: 25.1088	valid_0's l2: 630.452
# [7200]	valid_0's rmse: 25.1014	valid_0's l2: 630.082
# [7600]	valid_0's rmse: 25.0931	valid_0's l2: 629.661
# [8000]	valid_0's rmse: 25.0899	valid_0's l2: 629.504
# [8400]	valid_0's rmse: 25.0877	valid_0's l2: 629.395
# [8800]	valid_0's rmse: 25.0847	valid_0's l2: 629.244
# [9200]	valid_0's rmse: 25.0825	valid_0's l2: 629.13
# [9600]	valid_0's rmse: 25.081	valid_0's l2: 629.057
# [10000]	valid_0's rmse: 25.079	valid_0's l2: 628.957
# Did not meet early stopping. Best iteration is:
# [9984]	valid_0's rmse: 25.079	valid_0's l2: 628.954
# err:  25.078953487409347
# Training until validation scores don't improve for 200 rounds.
# [400]	valid_0's rmse: 28.3321	valid_0's l2: 802.705
# [800]	valid_0's rmse: 27.3791	valid_0's l2: 749.618
# [1200]	valid_0's rmse: 26.8845	valid_0's l2: 722.774
# [1600]	valid_0's rmse: 26.571	valid_0's l2: 706.017
# [2000]	valid_0's rmse: 26.3746	valid_0's l2: 695.62
# [2400]	valid_0's rmse: 26.2382	valid_0's l2: 688.441
# [2800]	valid_0's rmse: 26.1389	valid_0's l2: 683.242
# [3200]	valid_0's rmse: 26.0484	valid_0's l2: 678.52
# [3600]	valid_0's rmse: 25.9766	valid_0's l2: 674.786
# [4000]	valid_0's rmse: 25.9444	valid_0's l2: 673.113
# [4400]	valid_0's rmse: 25.9082	valid_0's l2: 671.235
# [4800]	valid_0's rmse: 25.882	valid_0's l2: 669.878
# [5200]	valid_0's rmse: 25.8717	valid_0's l2: 669.346
# [5600]	valid_0's rmse: 25.8545	valid_0's l2: 668.456
# [6000]	valid_0's rmse: 25.8445	valid_0's l2: 667.94
# [6400]	valid_0's rmse: 25.8356	valid_0's l2: 667.478
# [6800]	valid_0's rmse: 25.8295	valid_0's l2: 667.161
# [7200]	valid_0's rmse: 25.8238	valid_0's l2: 666.868
# [7600]	valid_0's rmse: 25.822	valid_0's l2: 666.778
# [8000]	valid_0's rmse: 25.8186	valid_0's l2: 666.599
# [8400]	valid_0's rmse: 25.8166	valid_0's l2: 666.499
# [8800]	valid_0's rmse: 25.8134	valid_0's l2: 666.334
# [9200]	valid_0's rmse: 25.8117	valid_0's l2: 666.246
# [9600]	valid_0's rmse: 25.8093	valid_0's l2: 666.118
# [10000]	valid_0's rmse: 25.8072	valid_0's l2: 666.01
# Did not meet early stopping. Best iteration is:
# [9956]	valid_0's rmse: 25.8069	valid_0's l2: 665.996
# err:  25.806901588290206
# Training until validation scores don't improve for 200 rounds.
# [400]	valid_0's rmse: 28.381	valid_0's l2: 805.482
# [800]	valid_0's rmse: 27.2542	valid_0's l2: 742.79
# [1200]	valid_0's rmse: 26.7615	valid_0's l2: 716.177
# [1600]	valid_0's rmse: 26.4482	valid_0's l2: 699.508
# [2000]	valid_0's rmse: 26.2545	valid_0's l2: 689.296
# [2400]	valid_0's rmse: 26.1159	valid_0's l2: 682.039
# [2800]	valid_0's rmse: 26.0292	valid_0's l2: 677.517
# [3200]	valid_0's rmse: 25.9564	valid_0's l2: 673.732
# [3600]	valid_0's rmse: 25.8993	valid_0's l2: 670.771
# [4000]	valid_0's rmse: 25.8631	valid_0's l2: 668.902
# [4400]	valid_0's rmse: 25.8391	valid_0's l2: 667.661
# [4800]	valid_0's rmse: 25.8081	valid_0's l2: 666.056
# [5200]	valid_0's rmse: 25.7804	valid_0's l2: 664.628
# [5600]	valid_0's rmse: 25.7599	valid_0's l2: 663.572
# [6000]	valid_0's rmse: 25.7435	valid_0's l2: 662.728
# [6400]	valid_0's rmse: 25.7303	valid_0's l2: 662.049
# [6800]	valid_0's rmse: 25.7237	valid_0's l2: 661.711
# [7200]	valid_0's rmse: 25.716	valid_0's l2: 661.311
# [7600]	valid_0's rmse: 25.7087	valid_0's l2: 660.938
# [8000]	valid_0's rmse: 25.7027	valid_0's l2: 660.628
# [8400]	valid_0's rmse: 25.6968	valid_0's l2: 660.325
# [8800]	valid_0's rmse: 25.6918	valid_0's l2: 660.067
# [9200]	valid_0's rmse: 25.6884	valid_0's l2: 659.893
# [9600]	valid_0's rmse: 25.6865	valid_0's l2: 659.795
# [10000]	valid_0's rmse: 25.6835	valid_0's l2: 659.64
# Did not meet early stopping. Best iteration is:
# [9997]	valid_0's rmse: 25.6834	valid_0's l2: 659.636
# err:  25.683388802238312
# Training until validation scores don't improve for 200 rounds.
# [400]	valid_0's rmse: 25.3544	valid_0's l2: 642.847
# [800]	valid_0's rmse: 24.159	valid_0's l2: 583.656
# [1200]	valid_0's rmse: 23.5042	valid_0's l2: 552.445
# [1600]	valid_0's rmse: 23.1593	valid_0's l2: 536.355
# [2000]	valid_0's rmse: 22.9366	valid_0's l2: 526.089
# [2400]	valid_0's rmse: 22.8128	valid_0's l2: 520.422
# [2800]	valid_0's rmse: 22.7234	valid_0's l2: 516.351
# [3200]	valid_0's rmse: 22.6435	valid_0's l2: 512.729
# [3600]	valid_0's rmse: 22.5976	valid_0's l2: 510.651
# [4000]	valid_0's rmse: 22.5606	valid_0's l2: 508.982
# [4400]	valid_0's rmse: 22.5302	valid_0's l2: 507.612
# [4800]	valid_0's rmse: 22.5104	valid_0's l2: 506.718
# [5200]	valid_0's rmse: 22.4913	valid_0's l2: 505.857
# [5600]	valid_0's rmse: 22.4796	valid_0's l2: 505.331
# [6000]	valid_0's rmse: 22.466	valid_0's l2: 504.72
# [6400]	valid_0's rmse: 22.4576	valid_0's l2: 504.342
# [6800]	valid_0's rmse: 22.4492	valid_0's l2: 503.965
# [7200]	valid_0's rmse: 22.4414	valid_0's l2: 503.617
# [7600]	valid_0's rmse: 22.4357	valid_0's l2: 503.359
# [8000]	valid_0's rmse: 22.432	valid_0's l2: 503.195
# [8400]	valid_0's rmse: 22.4283	valid_0's l2: 503.028
# [8800]	valid_0's rmse: 22.4241	valid_0's l2: 502.839
# [9200]	valid_0's rmse: 22.4235	valid_0's l2: 502.813
# [9600]	valid_0's rmse: 22.4217	valid_0's l2: 502.731
# [10000]	valid_0's rmse: 22.4203	valid_0's l2: 502.668
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's rmse: 22.4203	valid_0's l2: 502.668
# err:  22.420264449753503
# Training until validation scores don't improve for 200 rounds.
# [400]	valid_0's rmse: 28.1882	valid_0's l2: 794.576
# [800]	valid_0's rmse: 27.2354	valid_0's l2: 741.767
# [1200]	valid_0's rmse: 26.7232	valid_0's l2: 714.131
# [1600]	valid_0's rmse: 26.4415	valid_0's l2: 699.15
# [2000]	valid_0's rmse: 26.2464	valid_0's l2: 688.871
# [2400]	valid_0's rmse: 26.1239	valid_0's l2: 682.459
# [2800]	valid_0's rmse: 26.0547	valid_0's l2: 678.848
# [3200]	valid_0's rmse: 26.0089	valid_0's l2: 676.462
# [3600]	valid_0's rmse: 25.9798	valid_0's l2: 674.952
# [4000]	valid_0's rmse: 25.947	valid_0's l2: 673.245
# [4400]	valid_0's rmse: 25.9228	valid_0's l2: 671.991
# [4800]	valid_0's rmse: 25.9047	valid_0's l2: 671.053
# [5200]	valid_0's rmse: 25.883	valid_0's l2: 669.932
# [5600]	valid_0's rmse: 25.8689	valid_0's l2: 669.199
# [6000]	valid_0's rmse: 25.8552	valid_0's l2: 668.493
# [6400]	valid_0's rmse: 25.8492	valid_0's l2: 668.183
# [6800]	valid_0's rmse: 25.8439	valid_0's l2: 667.908
# [7200]	valid_0's rmse: 25.8358	valid_0's l2: 667.488
# [7600]	valid_0's rmse: 25.8298	valid_0's l2: 667.18
# [8000]	valid_0's rmse: 25.8264	valid_0's l2: 667.004
# [8400]	valid_0's rmse: 25.8231	valid_0's l2: 666.835
# [8800]	valid_0's rmse: 25.8213	valid_0's l2: 666.741
# [9200]	valid_0's rmse: 25.8193	valid_0's l2: 666.637
# [9600]	valid_0's rmse: 25.8166	valid_0's l2: 666.495
# [10000]	valid_0's rmse: 25.8164	valid_0's l2: 666.484
# Did not meet early stopping. Best iteration is:
# [9853]	valid_0's rmse: 25.816	valid_0's l2: 666.467
# err:  25.81602673713116
# Training until validation scores don't improve for 200 rounds.
# [400]	valid_0's rmse: 23.9452	valid_0's l2: 573.375
# [800]	valid_0's rmse: 22.9624	valid_0's l2: 527.27
# [1200]	valid_0's rmse: 22.5224	valid_0's l2: 507.257
# [1600]	valid_0's rmse: 22.2013	valid_0's l2: 492.896
# [2000]	valid_0's rmse: 21.9855	valid_0's l2: 483.362
# [2400]	valid_0's rmse: 21.8633	valid_0's l2: 478.005
# [2800]	valid_0's rmse: 21.7871	valid_0's l2: 474.676
# [3200]	valid_0's rmse: 21.7235	valid_0's l2: 471.908
# [3600]	valid_0's rmse: 21.679	valid_0's l2: 469.98
# [4000]	valid_0's rmse: 21.6623	valid_0's l2: 469.257
# [4400]	valid_0's rmse: 21.6315	valid_0's l2: 467.921
# [4800]	valid_0's rmse: 21.6086	valid_0's l2: 466.934
# [5200]	valid_0's rmse: 21.5923	valid_0's l2: 466.226
# [5600]	valid_0's rmse: 21.578	valid_0's l2: 465.61
# [6000]	valid_0's rmse: 21.5695	valid_0's l2: 465.243
# [6400]	valid_0's rmse: 21.5607	valid_0's l2: 464.862
# [6800]	valid_0's rmse: 21.5517	valid_0's l2: 464.475
# [7200]	valid_0's rmse: 21.5486	valid_0's l2: 464.344
# [7600]	valid_0's rmse: 21.5461	valid_0's l2: 464.233
# [8000]	valid_0's rmse: 21.5436	valid_0's l2: 464.127
# [8400]	valid_0's rmse: 21.5421	valid_0's l2: 464.063
# Early stopping, best iteration is:
# [8236]	valid_0's rmse: 21.5418	valid_0's l2: 464.05
# err:  21.541820060652334
# Training until validation scores don't improve for 200 rounds.
# [400]	valid_0's rmse: 27.5474	valid_0's l2: 758.861
# [800]	valid_0's rmse: 26.539	valid_0's l2: 704.318
# [1200]	valid_0's rmse: 25.9321	valid_0's l2: 672.473
# [1600]	valid_0's rmse: 25.6282	valid_0's l2: 656.804
# [2000]	valid_0's rmse: 25.4509	valid_0's l2: 647.75
# [2400]	valid_0's rmse: 25.3198	valid_0's l2: 641.09
# [2800]	valid_0's rmse: 25.2319	valid_0's l2: 636.65
# [3200]	valid_0's rmse: 25.1619	valid_0's l2: 633.122
# [3600]	valid_0's rmse: 25.1024	valid_0's l2: 630.13
# [4000]	valid_0's rmse: 25.0613	valid_0's l2: 628.067
# [4400]	valid_0's rmse: 25.0363	valid_0's l2: 626.817
# [4800]	valid_0's rmse: 25.0093	valid_0's l2: 625.464
# [5200]	valid_0's rmse: 24.9916	valid_0's l2: 624.582
# [5600]	valid_0's rmse: 24.9793	valid_0's l2: 623.964
# [6000]	valid_0's rmse: 24.9644	valid_0's l2: 623.221
# [6400]	valid_0's rmse: 24.9517	valid_0's l2: 622.589
# [6800]	valid_0's rmse: 24.9438	valid_0's l2: 622.194
# [7200]	valid_0's rmse: 24.9388	valid_0's l2: 621.944
# [7600]	valid_0's rmse: 24.9358	valid_0's l2: 621.796
# [8000]	valid_0's rmse: 24.9302	valid_0's l2: 621.514
# [8400]	valid_0's rmse: 24.9262	valid_0's l2: 621.314
# [8800]	valid_0's rmse: 24.9229	valid_0's l2: 621.151
# [9200]	valid_0's rmse: 24.9207	valid_0's l2: 621.039
# [9600]	valid_0's rmse: 24.9186	valid_0's l2: 620.937
# [10000]	valid_0's rmse: 24.9161	valid_0's l2: 620.81
# Did not meet early stopping. Best iteration is:
# [9999]	valid_0's rmse: 24.916	valid_0's l2: 620.809
# err:  24.91603762443325
# Training until validation scores don't improve for 200 rounds.
# [400]	valid_0's rmse: 24.5233	valid_0's l2: 601.391
# [800]	valid_0's rmse: 23.3857	valid_0's l2: 546.89
# [1200]	valid_0's rmse: 22.7938	valid_0's l2: 519.556
# [1600]	valid_0's rmse: 22.5076	valid_0's l2: 506.591
# [2000]	valid_0's rmse: 22.2977	valid_0's l2: 497.187
# [2400]	valid_0's rmse: 22.163	valid_0's l2: 491.198
# [2800]	valid_0's rmse: 22.0736	valid_0's l2: 487.243
# [3200]	valid_0's rmse: 22.007	valid_0's l2: 484.308
# [3600]	valid_0's rmse: 21.9471	valid_0's l2: 481.674
# [4000]	valid_0's rmse: 21.9002	valid_0's l2: 479.618
# [4400]	valid_0's rmse: 21.8635	valid_0's l2: 478.013
# [4800]	valid_0's rmse: 21.8434	valid_0's l2: 477.133
# [5200]	valid_0's rmse: 21.8303	valid_0's l2: 476.561
# [5600]	valid_0's rmse: 21.811	valid_0's l2: 475.719
# [6000]	valid_0's rmse: 21.7972	valid_0's l2: 475.116
# [6400]	valid_0's rmse: 21.7891	valid_0's l2: 474.763
# [6800]	valid_0's rmse: 21.7826	valid_0's l2: 474.48
# [7200]	valid_0's rmse: 21.7774	valid_0's l2: 474.253
# [7600]	valid_0's rmse: 21.7717	valid_0's l2: 474.005
# [8000]	valid_0's rmse: 21.7666	valid_0's l2: 473.786
# [8400]	valid_0's rmse: 21.7635	valid_0's l2: 473.652

# %%
# # s.to_csv('colabtry4.csv',index=False) ,reg_alpha=1,reg_lambda=10
# # s.target.describe()
# err=[]
# y_pred_tot=[]
# from sklearn.model_selection import KFold,StratifiedKFold
# fold=StratifiedKFold(n_splits=5,shuffle=True,random_state=1994)
# i=1
# for train_index, test_index in fold.split(X,y_bin):
#     X_train, X_test = X.iloc[train_index], X.iloc[test_index]
#     y_train, y_test = y[train_index], y[test_index]
#     m=LGBMRegressor(n_estimators=10000,random_state=1994,learning_rate=0.03,num_leaves=50,boosting_type='gbdt',feature_fraction=0.6,
#                 objective='regression',min_child_samples=12)
#     m.fit(X_train,y_train,eval_set=[(X_test, y_test)],eval_metric='rmse', early_stopping_rounds=200,verbose=400)
#     preds=m.predict(X_test)
#     print("err: ",np.sqrt(mean_squared_error(y_test,preds)))
#     err.append(np.sqrt(mean_squared_error(y_test,preds)))
#     p = m.predict(Xtest)
#     i=i+1
#     y_pred_tot.append(p)

# %%
np.mean(err)
# Out:
# 24.22103461016549

# %%
s['target']=np.mean(y_pred_tot,0)
s
# Out:
#             Place_ID X Date     target
# 0      0OS9LVX X 2020-01-02  46.074689
# 1      0OS9LVX X 2020-01-03  35.531098
# 2      0OS9LVX X 2020-01-04  32.588001
# 3      0OS9LVX X 2020-01-05  36.428560
# 4      0OS9LVX X 2020-01-06  33.887611
# ...                     ...        ...
# 16131  ZZDJZMS X 2020-03-31  35.300739
# 16132  ZZDJZMS X 2020-04-01  47.987413
# 16133  ZZDJZMS X 2020-04-02  50.178225
# 16134  ZZDJZMS X 2020-04-03  36.965615
# 16135  ZZDJZMS X 2020-04-04  34.462036
#
# [16136 rows x 2 columns]

# %%
s.to_csv('zindi_colab_try2_lgbm2.csv',index=False)

# %%
from google.colab import files
files.download('zindi_colab_try2_lgbm2.csv')
